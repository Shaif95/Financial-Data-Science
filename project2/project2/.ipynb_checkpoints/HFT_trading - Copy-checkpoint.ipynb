# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.decomposition import PCA
from sklearn import svm
import seaborn as sns
from matplotlib.colors import ListedColormap
from sklearn import neighbors
import matplotlib.pyplot as plt
from pandas.plotting import parallel_coordinates
from sklearn.preprocessing import StandardScaler
from sklearn import decomposition
import scipy
from sklearn.manifold import TSNE
from pandas.plotting import parallel_coordinates
from sklearn import decomposition
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.decomposition import PCA
from sklearn import svm
import seaborn as sns
from matplotlib.colors import ListedColormap
from sklearn import neighbors
import matplotlib.pyplot as plt
from pandas.plotting import parallel_coordinates
from sklearn.preprocessing import StandardScaler
from sklearn import decomposition
import scipy
from math import  pi, exp,log, sqrt
from scipy.stats import norm
from sklearn.manifold import TSNE
import seaborn as sn
from sklearn.datasets import make_friedman1
from sklearn.decomposition import SparsePCA
from dask import dataframe as dd
from numpy import abs
from math import fabs

# %%
path = 'dataset/AAPL_n.csv'
df = pd.read_csv(path)
df.head(3)
# Out:
#    Unnamed: 0           Date  marketAverage  marketChangeOverTime  \
# 0           0  2/1/2019 9:30        167.058              0.000000
# 1           1  2/1/2019 9:31        167.182              0.000742
# 2           2  2/1/2019 9:32        167.051             -0.000042
#
#    marketClose  marketHigh  marketLow  marketNotional  marketNumberOfTrades  \
# 0      167.150      167.55     166.67    1.319461e+08                  1766
# 1      167.175      167.42     166.80    2.853055e+07                  1143
# 2      166.910      167.20     166.88    2.232776e+07                  1016
#
#    marketOpen  marketVolume    return
# 0      166.93        789821 -0.024172
# 1      167.21        170656  0.000060
# 2      167.17        133658 -0.001586

# %%
path = 'dataset/AAPL_n.csv'
def read():
    df = pd.read_csv(path)
    return df

# %%
df[-3:].head(3)
# Out:
#       Unnamed: 0             Date  marketAverage  marketChangeOverTime  \
# 5847        5847  2/22/2019 15:57        172.690              0.006704
# 5848        5848  2/22/2019 15:58        172.677              0.006628
# 5849        5849  2/22/2019 15:59        172.815              0.007433
#
#       marketClose  marketHigh  marketLow  marketNotional  \
# 5847       172.67      172.73     172.67     17278873.15
# 5848       172.72      172.74     172.64     25217590.60
# 5849       172.95      173.00     172.70     92472307.19
#
#       marketNumberOfTrades  marketOpen  marketVolume    return
# 5847                   690      172.69        100057 -0.000116
# 5848                  1123      172.68        146039  0.000347
# 5849                  3037      172.72        535095  0.000579

# %%
df[['marketClose','return']].plot(subplots = True,color = 'blue',figsize=(8,6))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
def cal(data,k,p,t):

    import numpy as np
    df = data.copy()
    df.loc[:, 'temp_return'] = 0
    df.loc[:, 'sum_return']  = 0
    
    
    for i in range(1, k + 1):
        
        df.loc[:, 'temp_return'] = (df.loc[:, 'marketAverage'].shift(-i) - df.loc[:, 'marketClose']) / df.loc[:, 'marketClose']
        df.loc[np.fabs(df.temp_return) > p, 'sum_return'] += df.loc[(np.fabs(df.temp_return) > p), 'temp_return']

            
    df.loc[df.sum_return >= t, 'action'] = 'buy'    
    df.loc[(df.sum_return < t) & (df.sum_return > -t), 'action'] = 'hold'  
    df.loc[df.sum_return <= -t, 'action'] = 'sell'
    
    return df[['marketAverage' ,'marketClose','marketHigh','marketLow','marketOpen','return','temp','sum','action']]

# %%
df = read()

data = df

calc = cal(data,10,.0005,.01)

calc.head(5)
# Out:
# C:\Users\chsha\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#    marketAverage  marketClose  marketHigh  marketLow  marketOpen    return  \
# 0        167.058      167.150      167.55     166.67      166.93 -0.024172
# 1        167.182      167.175      167.42     166.80      167.21  0.000060
# 2        167.051      166.910      167.20     166.88      167.17 -0.001586
# 3        166.945      166.958      167.11     166.77      166.97  0.000150
# 4        167.045      167.180      167.19     166.92      166.96  0.001257
#
#        temp       sum action
# 0  0.003075  0.003087   hold
# 1  0.004098  0.005784   hold
# 2  0.005770  0.026643    buy
# 3  0.004941  0.028989    buy
# ...

# %%
calc.describe()
# Out:
#        marketAverage  marketClose   marketHigh    marketLow   marketOpen  \
# count    5850.000000  5850.000000  5850.000000  5850.000000  5850.000000
# mean      171.078756   170.247891   171.157618   170.955011   171.077983
# std         1.723671     5.087462     1.729208     1.874900     1.724871
# min       166.021000   142.680000   166.070000   142.680000   166.030000
# 25%       170.187250   170.100000   170.260000   170.110000   170.190000
# 50%       170.856000   170.810000   170.920000   170.793000   170.857500
# 75%       172.103750   172.164750   172.171500   172.000000   172.103750
# max       175.499000   175.470000   175.570000   175.420000   175.470000
#
#             return         temp          sum
# count  5850.000000  5840.000000  5850.000000
# mean     -0.000007     0.005884     0.058482
# std       0.000874     0.033425     0.333836
# min      -0.037340    -0.011998    -0.110454
# 25%      -0.000289    -0.000735    -0.003825
# ...

# %%
calc['sum'].mean()
# Out:
# 0.05924543211626489
